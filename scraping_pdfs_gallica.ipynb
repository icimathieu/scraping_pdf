# %% [markdown]
# ## Lecture fichier txt des arks

# %%
import requests
import re
import pandas as pd
from bs4 import BeautifulSoup
from tqdm import tqdm
import time
import ast
import json
import urllib.request, urllib.error, urllib.parse
import os

# %%
headers= {"User-Agent": "Mozilla/5.0"}
cookie = {"JSESSIONID": "914B3F24C87905DA2C84EFE48D3F7093"}

# %%
start_date = 1883
end_date = 1889

# %% [markdown]
# Faire de ma liste de revues liste des numéros (via liste des revues par année)

# %%
chemin1 = './arks_revues.json'
with open(chemin1, mode='r', encoding='utf-8') as f : 
    dico_revues = ast.literal_eval(f.read())

# %%
dico_arks = { "numeros" : [],"urls" : []}
for revue in dico_revues : 
    url_revue = dico_revues[revue]
    for i in tqdm(range(start_date, end_date)):
        for j in tqdm(range(1, 13)): #éventuellement raffiner avec boucle sur les jours du mois
            url = url_revue+f"/date{i}{j:02d}01"
            response = requests.get(url, headers=headers, cookies=cookie)
            print(response.url)
            if response.status_code == 200 and response.url[-5:] == ".item" :
                dico_arks["urls"].append(response.url[23:-5])
                dico_arks["numeros"].append(revue+url[-8:])
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18830101
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18830201
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18830301
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18830401
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18830501
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18830601
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18830701
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18830801
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18830901
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18831001
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18831101
# 100%|██████████| 12/12 [00:03<00:00,  3.83it/s]
#  17%|█▋        | 1/6 [00:03<00:15,  3.13s/it]
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18831201
# https://gallica.bnf.fr/ark:/12148/bpt6k2151022.item
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18840201
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18840301
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18840401
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18840501
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18840601
# https://gallica.bnf.fr/ark:/12148/bpt6k215103f.item
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18840801
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18840901
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18841001
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18841101
# 100%|██████████| 12/12 [00:04<00:00,  2.96it/s]
#  33%|███▎      | 2/6 [00:07<00:14,  3.68s/it]
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18841201
# https://gallica.bnf.fr/ark:/12148/bpt6k215104t.item
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18850201
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18850301
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18850401
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18850501
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18850601
# https://gallica.bnf.fr/ark:/12148/bpt6k2151056.item
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18850801
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18850901
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18851001
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18851101
# 100%|██████████| 12/12 [00:05<00:00,  2.18it/s]
#  50%|█████     | 3/6 [00:12<00:13,  4.52s/it]
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18851201
# https://gallica.bnf.fr/ark:/12148/bpt6k215106k.item
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18860201
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18860301
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18860401
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18860501
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18860601
# https://gallica.bnf.fr/ark:/12148/bpt6k215107z.item
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18860801
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18860901
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18861001
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18861101
# 100%|██████████| 12/12 [00:04<00:00,  2.54it/s]
#  67%|██████▋   | 4/6 [00:17<00:09,  4.60s/it]
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18861201
# https://gallica.bnf.fr/ark:/12148/bpt6k215108b.item
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18870201
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18870301
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18870401
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18870501
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18870601
# https://gallica.bnf.fr/ark:/12148/bpt6k215109q.item
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18870801
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18870901
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18871001
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18871101
# 100%|██████████| 12/12 [00:04<00:00,  2.84it/s]
#  83%|████████▎ | 5/6 [00:21<00:04,  4.47s/it]
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18871201
# https://gallica.bnf.fr/ark:/12148/bpt6k215110n.item
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18880201
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18880301
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18880401
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18880501
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18880601
# https://gallica.bnf.fr/ark:/12148/bpt6k2151111.item
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18880801
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18880901
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18881001
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18881101
# 100%|██████████| 12/12 [00:04<00:00,  2.79it/s]
# 100%|██████████| 6/6 [00:25<00:00,  4.33s/it]
# https://gallica.bnf.fr/ark:/12148/cb34378388w/date18881201
#   0%|          | 0/6 [00:00<?, ?it/s]
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18830101
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18830201
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18830301
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18830401
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18830501
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18830601
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18830701
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18830801
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18830901
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18831001
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18831101
# 100%|██████████| 12/12 [00:03<00:00,  3.83it/s]
#  17%|█▋        | 1/6 [00:03<00:15,  3.13s/it]
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18831201
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18840101
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18840201
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18840301
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18840401
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18840501
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18840601
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18840701
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18840801
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18840901
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18841001
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18841101
# 100%|██████████| 12/12 [00:03<00:00,  3.94it/s]
#  33%|███▎      | 2/6 [00:06<00:12,  3.08s/it]
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18841201
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18850101
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18850201
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18850301
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18850401
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18850501
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18850601
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18850701
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18850801
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18850901
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18851001
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18851101
# 100%|██████████| 12/12 [00:02<00:00,  4.05it/s]
#  50%|█████     | 3/6 [00:09<00:09,  3.03s/it]
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18851201
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18860101
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18860201
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18860301
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18860401
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18860501
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18860601
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18860701
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18860801
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18860901
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18861001
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18861101
# 100%|██████████| 12/12 [00:08<00:00,  1.49it/s]
#  67%|██████▋   | 4/6 [00:17<00:10,  5.02s/it]
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18861201
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18870101
# https://gallica.bnf.fr/ark:/12148/bpt6k5797810g.item
# https://gallica.bnf.fr/ark:/12148/bpt6k5797811w.item
# https://gallica.bnf.fr/ark:/12148/bpt6k57978129.item
# https://gallica.bnf.fr/ark:/12148/bpt6k5797813q.item
# https://gallica.bnf.fr/ark:/12148/bpt6k57978144.item
# https://gallica.bnf.fr/ark:/12148/bpt6k5797815j.item
# https://gallica.bnf.fr/ark:/12148/bpt6k5797816z.item
# https://gallica.bnf.fr/ark:/12148/bpt6k5797817c.item
# https://gallica.bnf.fr/ark:/12148/bpt6k5797818s.item
# https://gallica.bnf.fr/ark:/12148/bpt6k57978196.item
# 100%|██████████| 12/12 [00:14<00:00,  1.18s/it]
#  83%|████████▎ | 5/6 [00:31<00:08,  8.32s/it]
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18871201
# https://gallica.bnf.fr/ark:/12148/cb34348753q/date18880101
# https://gallica.bnf.fr/ark:/12148/bpt6k5791274g.item
# https://gallica.bnf.fr/ark:/12148/bpt6k5791275w.item
# https://gallica.bnf.fr/ark:/12148/bpt6k57912769.item
# https://gallica.bnf.fr/ark:/12148/bpt6k5791277q.item
# https://gallica.bnf.fr/ark:/12148/bpt6k57912784.item
# https://gallica.bnf.fr/ark:/12148/bpt6k5791279j.item
# https://gallica.bnf.fr/ark:/12148/bpt6k57912806.item
# https://gallica.bnf.fr/ark:/12148/bpt6k5791281m.item
# https://gallica.bnf.fr/ark:/12148/bpt6k57912821.item
# https://gallica.bnf.fr/ark:/12148/bpt6k5791283f.item
# 100%|██████████| 12/12 [00:10<00:00,  1.14it/s]
# 100%|██████████| 6/6 [00:41<00:00,  6.98s/it]
# https://gallica.bnf.fr/ark:/12148/bpt6k57912858.item

# %%
with open("arks_numeros.json", "w", encoding="utf-8") as out: 
    json.dump(dico_arks, out)

# %% [markdown]
# ## scraping gallica des pdfs (ou jpeg??!!) avec enregistrement dans répertoire

# %%
chemin2 = './arks_numeros.json'#liste de listes ?
with open(chemin2, mode='r', encoding='utf-8') as f : 
    dico_arks2 = ast.literal_eval(f.read())

# %% [markdown]
# ### en faire un tableau intermédiaire

# %%
df_arks = pd.DataFrame(dico_arks2)
open('tableau_arks.csv', mode='w', encoding='utf-8').write(df_arks.to_csv())
# Out:
# 1825

# %%
dico_arks2
# Out:
# {'numeros': ['revue_scientifique18840101',
#   'revue_scientifique18840701',
#   'revue_scientifique18850101',
#   'revue_scientifique18850701',
#   'revue_scientifique18860101',
#   'revue_scientifique18860701',
#   'revue_scientifique18870101',
#   'revue_scientifique18870701',
#   'revue_scientifique18880101',
#   'revue_scientifique18880701',
#   'annales_institut_pasteur18870201',
#   'annales_institut_pasteur18870301',
#   'annales_institut_pasteur18870401',
#   'annales_institut_pasteur18870501',
#   'annales_institut_pasteur18870601',
#   'annales_institut_pasteur18870701',
#   'annales_institut_pasteur18870801',
#   'annales_institut_pasteur18870901',
#   'annales_institut_pasteur18871001',
#   'annales_institut_pasteur18871101',
#   'annales_institut_pasteur18880201',
#   'annales_institut_pasteur18880301',
#   'annales_institut_pasteur18880401',
#   'annales_institut_pasteur18880501',
#   'annales_institut_pasteur18880601',
#   'annales_institut_pasteur18880701',
#   'annales_institut_pasteur18880801',
#   'annales_institut_pasteur18880901',
#   'annales_institut_pasteur18881001',
#   'annales_institut_pasteur18881101',
#   'annales_institut_pasteur18881201'],
#  'urls': ['ark:/12148/bpt6k2151022',
#   'ark:/12148/bpt6k215103f',
#   'ark:/12148/bpt6k215104t',
#   'ark:/12148/bpt6k2151056',
#   'ark:/12148/bpt6k215106k',
#   'ark:/12148/bpt6k215107z',
#   'ark:/12148/bpt6k215108b',
#   'ark:/12148/bpt6k215109q',
#   'ark:/12148/bpt6k215110n',
#   'ark:/12148/bpt6k2151111',
#   'ark:/12148/bpt6k5797810g',
#   'ark:/12148/bpt6k5797811w',
#   'ark:/12148/bpt6k57978129',
#   'ark:/12148/bpt6k5797813q',
#   'ark:/12148/bpt6k57978144',
#   'ark:/12148/bpt6k5797815j',
#   'ark:/12148/bpt6k5797816z',
#   'ark:/12148/bpt6k5797817c',
#   'ark:/12148/bpt6k5797818s',
#   'ark:/12148/bpt6k57978196',
#   'ark:/12148/bpt6k5791274g',
#   'ark:/12148/bpt6k5791275w',
#   'ark:/12148/bpt6k57912769',
#   'ark:/12148/bpt6k5791277q',
#   'ark:/12148/bpt6k57912784',
#   'ark:/12148/bpt6k5791279j',
#   'ark:/12148/bpt6k57912806',
#   'ark:/12148/bpt6k5791281m',
#   'ark:/12148/bpt6k57912821',
#   'ark:/12148/bpt6k5791283f',
#   'ark:/12148/bpt6k57912858']}

# %% [markdown]
# ## Récupérer jpg gallica (non)

# %%
for numero, ark in tqdm(zip(dico_arks2['numeros'], dico_arks2['urls'])) :
    os.mkdir("/Users/mathieu/Documents/memoire/test_ocr/"+numero)
    dir_local = "/Users/mathieu/Documents/memoire/test_ocr/"+numero
    for page in tqdm(range(1, 1001)) :
        time.sleep(2)
        jpgfile = os.path.join(dir_local, numero + "_" + str(page) + ".jpg")
        url_jpg = 'http://gallica.bnf.fr/iiif/' + ark + '/f' + str(page) + '/full/3000/0/native.jpg'
        response = requests.get(url_jpg, headers=headers)
        if response.status_code == 200 : 
            time.sleep(2)
            urllib.request.urlretrieve(url_jpg, jpgfile)      
    time.sleep(10)
# Out:
# 0it [00:00, ?it/s]
# revue_scientifique18840101 ark:/12148/bpt6k2151022
#   1%|          | 7/1000 [00:38<1:31:48,  5.55s/it]
# 0it [00:38, ?it/s]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[19], line 16
#      14     if response.status_code == 200 :
#      15         time.sleep(2)
# ---> 16         urllib.request.urlretrieve(url_jpg, jpgfile)
#      17 time.sleep(10)
#
# File ~/miniconda3/lib/python3.13/urllib/request.py:214, in urlretrieve(url, filename, reporthook, data)
#     197 """
#     198 Retrieve a URL into a temporary location on disk.
#     199
#    (...)    210 data file as well as the resulting HTTPMessage object.
#     211 """
#     212 url_type, path = _splittype(url)
# --> 214 with contextlib.closing(urlopen(url, data)) as fp:
#     215     headers = fp.info()
#     217     # Just return the local path and the "headers" for file://
#     218     # URLs. No sense in performing a copy unless requested.
#
# File ~/miniconda3/lib/python3.13/urllib/request.py:189, in urlopen(url, data, timeout, context)
#     187 else:
#     188     opener = _opener
# --> 189 return opener.open(url, data, timeout)
#
# File ~/miniconda3/lib/python3.13/urllib/request.py:495, in OpenerDirector.open(self, fullurl, data, timeout)
#     493 for processor in self.process_response.get(protocol, []):
#     494     meth = getattr(processor, meth_name)
# --> 495     response = meth(req, response)
#     497 return response
#
# File ~/miniconda3/lib/python3.13/urllib/request.py:604, in HTTPErrorProcessor.http_response(self, request, response)
#     601 # According to RFC 2616, "2xx" code indicates that the client's
#     602 # request was successfully received, understood, and accepted.
#     603 if not (200 <= code < 300):
# --> 604     response = self.parent.error(
#     605         'http', request, response, code, msg, hdrs)
#     607 return response
#
# File ~/miniconda3/lib/python3.13/urllib/request.py:527, in OpenerDirector.error(self, proto, *args)
#     525     http_err = 0
#     526 args = (dict, proto, meth_name) + args
# --> 527 result = self._call_chain(*args)
#     528 if result:
#     529     return result
#
# File ~/miniconda3/lib/python3.13/urllib/request.py:466, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     464 for handler in handlers:
#     465     func = getattr(handler, meth_name)
# --> 466     result = func(*args)
#     467     if result is not None:
#     468         return result
#
# File ~/miniconda3/lib/python3.13/urllib/request.py:720, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     717 fp.read()
#     718 fp.close()
# --> 720 return self.parent.open(new, timeout=req.timeout)
#
# File ~/miniconda3/lib/python3.13/urllib/request.py:495, in OpenerDirector.open(self, fullurl, data, timeout)
#     493 for processor in self.process_response.get(protocol, []):
#     494     meth = getattr(processor, meth_name)
# --> 495     response = meth(req, response)
#     497 return response
#
# File ~/miniconda3/lib/python3.13/urllib/request.py:604, in HTTPErrorProcessor.http_response(self, request, response)
#     601 # According to RFC 2616, "2xx" code indicates that the client's
#     602 # request was successfully received, understood, and accepted.
#     603 if not (200 <= code < 300):
# --> 604     response = self.parent.error(
#     605         'http', request, response, code, msg, hdrs)
#     607 return response
#
# File ~/miniconda3/lib/python3.13/urllib/request.py:533, in OpenerDirector.error(self, proto, *args)
#     531 if http_err:
#     532     args = (dict, 'default', 'http_error_default') + orig_args
# --> 533     return self._call_chain(*args)
#
# File ~/miniconda3/lib/python3.13/urllib/request.py:466, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     464 for handler in handlers:
#     465     func = getattr(handler, meth_name)
# --> 466     result = func(*args)
#     467     if result is not None:
#     468         return result
#
# File ~/miniconda3/lib/python3.13/urllib/request.py:613, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     612 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 613     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 429: Too Many Requests

# %% [markdown]
# ## Récupérer pdf gallica

# %%
for numero, ark in tqdm(zip(dico_arks2['numeros'], dico_arks2['urls'])) :
    os.mkdir("/Users/mathieu/Documents/memoire/test_ocr/"+numero)
    dir_local = "/Users/mathieu/Documents/memoire/test_ocr/"+numero
    pdf_file = os.path.join(dir_local, numero + ".pdf")
    url_pdf = 'http://gallica.bnf.fr/' + ark + '.pdf'
    response = requests.get(url_pdf, headers=headers, cookies=cookie)
    time.sleep(1)
    if response.status_code == 200 : 
        urllib.request.urlretrieve(url_pdf, pdf_file)  
        time.sleep(1)
        print('un nv pdf téléchargé ! ')
# Out:
# 1it [02:03, 123.94s/it]
# un nv pdf téléchargé !
# 2it [04:51, 149.37s/it]
# un nv pdf téléchargé !
# 3it [07:42, 159.58s/it]
# un nv pdf téléchargé !
# 3it [08:30, 170.23s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 7
#       5 url_pdf = 'http://gallica.bnf.fr/' + ark + '.pdf'
#       6 response = requests.get(url_pdf, headers=headers, cookies=cookie)
# ----> 7 time.sleep(1)
#       8 if response.status_code == 200 :
#       9     urllib.request.urlretrieve(url_pdf, pdf_file)
#
# KeyboardInterrupt:

# %% [markdown]
# # En // faire un csv via panda avec métadonnées et liens arks_numeros ?!

# %% [markdown]
# ## from pdf to jpegs

# %%
import re
from pdf2image import convert_from_path, pdfinfo_from_path
from tqdm import tqdm

# %%
path_pdf = "/Users/mathieu/Documents/memoire/test_ocr/"

# %%
from glob import glob
files_name = []
for file in glob(path_pdf+"*"):
    print(file)
    files_name.append(file)
# Out:
# /Users/mathieu/Documents/memoire/test_ocr/revue_scientifique18840701
# /Users/mathieu/Documents/memoire/test_ocr/revue_scientifique18840101
# /Users/mathieu/Documents/memoire/test_ocr/revue_scientifique18850101

# %%
files_name = ["/Users/mathieu/Documents/memoire/test_ocr/revue_scientifique18840101"]

# %%
MAX_W, MAX_H = 1000, 1500
DPI1 = 150
POPPLER_PATH = "/opt/homebrew/bin"

def target_size(pdf_path, dpi, max_w, max_h):
    info = pdfinfo_from_path(pdf_path, poppler_path=POPPLER_PATH)
    # "Page size: 595.28 x 841.89 pts (A4)"
    m = re.search(r"([0-9.]+) x ([0-9.]+)", info.get("Page size", ""))
    if not m:
        return (max_w, max_h)  # fallback
    w_pts, h_pts = map(float, m.groups())
    w_px = w_pts / 72 * dpi
    h_px = h_pts / 72 * dpi
    scale = min(max_w / w_px, max_h / h_px, 1.0)
    return (int(w_px * scale), int(h_px * scale))

# %%
import glob
for file in tqdm(files_name) :
    path = file+"/*.pdf"
    pdf = glob.glob(path) 
    print(pdf)
    size1 = target_size(pdf[0], DPI1, MAX_W, MAX_H)
    print(size1)

    convert_from_path(pdf[0],
        dpi=DPI1,
        output_folder=file, 
        poppler_path=POPPLER_PATH,
        fmt="jpeg",
        output_file="page", size=size1)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ['/Users/mathieu/Documents/memoire/test_ocr/revue_scientifique18840101/revue_scientifique18840101.pdf']
# (999, 1500)
# 100%|██████████| 1/1 [01:08<00:00, 68.18s/it]
